# %% [raw]
# ---
# description: Implementation of various random initialization strategies suitable for
#   complex-valued layers.
# output-file: initialization.html
# title: Initialization
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# |output: asis
# | echo: false
show_doc(cplx_kaiming_normal_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_kaiming_normal_
#
# >      cplx_kaiming_normal_ (tensor, a=0.0, mode='fan_in',
# >                            nonlinearity='leaky_relu')

# %%
# |output: asis
# | echo: false
show_doc(cplx_kaiming_uniform_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_kaiming_uniform_
#
# >      cplx_kaiming_uniform_ (tensor, a=0.0, mode='fan_in',
# >                             nonlinearity='leaky_relu')

# %%
# |output: asis
# | echo: false
show_doc(cplx_xavier_normal_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_xavier_normal_
#
# >      cplx_xavier_normal_ (tensor, gain=1.0)

# %%
# |output: asis
# | echo: false
show_doc(cplx_xavier_uniform_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_xavier_uniform_
#
# >      cplx_xavier_uniform_ (tensor, gain=1.0)

# %%
# |output: asis
# | echo: false
show_doc(cplx_trabelsi_standard_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_trabelsi_standard_
#
# >      cplx_trabelsi_standard_ (tensor, kind='glorot')
#
# Standard complex initialization proposed in Trabelsi et al. (2018).

# %%
# |output: asis
# | echo: false
show_doc(cplx_trabelsi_independent_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L58){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_trabelsi_independent_
#
# >      cplx_trabelsi_independent_ (tensor, kind='glorot')
#
# Orthogonal complex initialization proposed in Trabelsi et al. (2018).

# %%
# |output: asis
# | echo: false
show_doc(cplx_normal_independent_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L91){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_normal_independent_
#
# >      cplx_normal_independent_ (tensor, a=0.0, b=1.0)

# %%
# |output: asis
# | echo: false
show_doc(cplx_uniform_independent_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L96){target="_blank" style="float:right; font-size:smaller"}
#
# ### cplx_uniform_independent_
#
# >      cplx_uniform_independent_ (tensor, a=0.0, b=1.0)

# %%
# |output: asis
# | echo: false
show_doc(ones_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L101){target="_blank" style="float:right; font-size:smaller"}
#
# ### ones_
#
# >      ones_ (tensor, imag_zero=False)

# %%
# |output: asis
# | echo: false
show_doc(zeros_)
# Out:
# ---
#
# [source](https://github.com/antonpf/mlmvn/blob/main/mlmvn/init.py#L109){target="_blank" style="float:right; font-size:smaller"}
#
# ### zeros_
#
# >      zeros_ (tensor)

# %%
weights = torch.randn(48, 100, dtype=torch.cdouble) / math.sqrt(48)

# %%
cplx_kaiming_normal_(weights)

# %%
cplx_trabelsi_standard_(weights)

# %%
ones_(weights, imag_zero=True)

# %%
cplx_normal_independent_(weights)

# %%
cplx_normal_independent_(weights)

# %%
weights
# Out:
# tensor([[ 0.4300+0.3978j,  0.4044+0.0886j, -0.0497+0.3637j,  ...,
#          -1.1625-0.2458j, -0.3606+1.3778j,  1.3233+0.1381j],
#         [-0.0352+0.4488j, -0.4317+0.1049j, -0.5743-0.0114j,  ...,
#           1.3755-0.1862j, -0.1263+1.6037j, -0.4251+0.0149j],
#         [ 0.1022+2.1415j, -0.3880-0.8916j,  0.9741+0.4967j,  ...,
#          -0.4281+1.6826j, -0.3992+0.4414j,  1.5657+0.3260j],
#         ...,
#         [-1.2332+1.4589j, -0.0185-3.0959j, -0.4712+2.1996j,  ...,
#          -0.4455+1.3777j,  0.4046-0.8535j,  1.3204+1.6157j],
#         [-1.3413-0.8369j, -1.7481+0.1788j,  0.2018-0.2512j,  ...,
#          -0.3099-1.4537j,  0.1969+3.0771j,  0.7079+1.1503j],
#         [ 1.7616+1.3624j,  0.6755+0.8201j, -0.2582+0.6527j,  ...,
#          -1.9779+0.6458j,  0.1358+0.4088j,  0.0482+0.3482j]],
#        dtype=torch.complex128)
